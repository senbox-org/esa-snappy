# %% [markdown]
# ## **SNAP Jupyter demo notebook**
# **Using a sequence of various SNAP operators to derive an OLCI L2 water product with a comprehensive set of water quantities.**
#
# This workflow has originally been realized in an XML graph manually built within the Okosat project. In summary, the steps are:
#
# - Read a subset of an S3 OLCI data product using the SNAP 'Read' operator
# - Apply an Idepix OLCI pixel classification.
# - Generate an appropriate tile cache  for the Idepix node.
# - Apply a vicarious calibration of the input radiances using the SNAP 'BandMaths' operator.
# - Create a merge product with the calibrated radiances and the Idepix classification, using the SNAP 'Merge' operator.
# - Apply the MphChl algorithm on the merge product, using the SNAP 'MphChl' operator.
# - Apply the C2RCC algorithm on the merge product, using the SNAP 'c2rcc.olci' operator.
# - Generate an appropriate tile cache  for the C2rcc node.
# - Derive further water quantities from MphChl and C2rcc, using the SNAP 'BandMaths' operator.
# - Do a final merge of all deriverd quantities, using the SNAP 'Merge' operator.
# - Write the result to a NetCDF file using the SNAP 'Write' operator.
# - Combine all steps (nodes) into a SNAP GPF xml graph, and run the graph using SNAPISTA.
#
# Complexity: advanced

# %% [markdown]
# ##### ***Some information on the Python environment:***

# %%
import os
import sys
print("Python version: " + sys.version)

import sysconfig
print("Location of esa_snappy package: " + sysconfig.get_paths()['purelib'] + os.sep + "esa_snappy")
# Out:
# Python version: 3.13.11 | packaged by Anaconda, Inc. | (main, Dec 10 2025, 21:21:58) [MSC v.1929 64 bit (AMD64)]
# Location of esa_snappy package: E:\olaf\miniconda_py313\Lib\site-packages\esa_snappy

# %% [markdown]
# ##### ***Import esa_snappy and snapista:***

# %%
import esa_snappy
import snapista

from snapista import Graph
from snapista import Operator
from snapista import TargetBand
from snapista import TargetBandDescriptors

# %% [markdown]
# ##### ***Set up a graph:***

# %%
try:
    g = Graph()
except Exception as ex:
    print("Cannot set up Snapista Graph():", ex)

# %% [markdown]
# ##### ***Add a 'Read' operator to the graph for reading example input:***

# %%
input_dir = os.getcwd() + os.sep + 'data'
input_filename = input_dir + os.sep +  'subset_0_of_S3A_OL_1_EFR____20180509T101337_20180509T101637_20180510T150001_0179_031_065_1980_MAR_O_NT_002.nc'
g.add_node(operator=Operator("Read", file=input_filename), node_id="Read")

# %% [markdown]
# ##### ***Add an 'Idepix.Olci' operator to the graph. Make sure that Idepix OLCI plugin has been installed in SNAP via Plugin Manager:***

# %%
g.add_node(operator=Operator('Idepix.Olci'), node_id="idepix_tobecached" ,source='Read')

# %% [markdown]
# ##### ***Add a 'TileCache' operator to the Idepix node:***

# %%
g.add_node(operator=Operator('TileCache', cacheSize='300'), node_id="idepix" ,source='idepix_tobecached')

# %% [markdown]
# ##### ***Add a 'BandMaths' operator to the graph for vicarious calibration:***

# %%
band_maths = Operator('BandMaths')

# %%
Oa01_radiance = TargetBand(name='Oa01_radiance', 
                           expression='feq(Oa01_radiance, 913.9812317630276, 1.0e-4) ? NaN : Oa01_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')                        
band_maths.targetBandDescriptors = TargetBandDescriptors([Oa01_radiance])

# %%
Oa02_radiance = TargetBand(name='Oa02_radiance', 
                           expression='feq(Oa02_radiance, 877.334085884504, 1.0e-4) ? NaN : Oa02_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa03_radiance = TargetBand(name='Oa03_radiance', 
                           expression='feq(Oa03_radiance, 796.1270730709657, 1.0e-4) ? NaN : Oa03_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa04_radiance = TargetBand(name='Oa04_radiance', 
                           expression='feq(Oa04_radiance, 754.9514318397269, 1.0e-4) ? NaN : Oa04_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa05_radiance = TargetBand(name='Oa05_radiance', 
                           expression='feq(Oa05_radiance, 661.5928710484877, 1.0e-4) ? NaN : Oa05_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa06_radiance = TargetBand(name='Oa06_radiance', 
                           expression='feq(Oa06_radiance, 809.60629854351287, 1.0e-4) ? NaN : Oa06_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa07_radiance = TargetBand(name='Oa07_radiance', 
                           expression='feq(Oa07_radiance, 576.1581395426765, 1.0e-4) ? NaN : Oa07_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa08_radiance = TargetBand(name='Oa08_radiance', 
                           expression='feq(Oa08_radiance, 574.4398430082947, 1.0e-4) ? NaN : Oa08_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa09_radiance = TargetBand(name='Oa09_radiance', 
                           expression='feq(Oa09_radiance, 623.2575185084715, 1.0e-4) ? NaN : Oa09_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa10_radiance = TargetBand(name='Oa10_radiance', 
                           expression='feq(Oa10_radiance, 506.83326963800937, 1.0e-4) ? NaN : Oa10_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa11_radiance = TargetBand(name='Oa11_radiance', 
                           expression='feq(Oa11_radiance, 442.70399916451424, 1.0e-4) ? NaN : Oa11_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa12_radiance = TargetBand(name='Oa12_radiance', 
                           expression='feq(Oa12_radiance, 471.8257776950486, 1.0e-4) ? NaN : Oa12_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa13_radiance = TargetBand(name='Oa13_radiance', 
                           expression='feq(Oa13_radiance, 491.30539988866076, 1.0e-4) ? NaN : Oa13_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa14_radiance = TargetBand(name='Oa14_radiance', 
                           expression='feq(Oa14_radiance, 566.9563756557181, 1.0e-4) ? NaN : Oa14_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa15_radiance = TargetBand(name='Oa15_radiance', 
                           expression='feq(Oa15_radiance, 345.2246211259626, 1.0e-4) ? NaN : Oa15_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa16_radiance = TargetBand(name='Oa16_radiance', 
                           expression='feq(Oa16_radiance, 347.5104749179445, 1.0e-4) ? NaN : Oa16_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa17_radiance = TargetBand(name='Oa17_radiance', 
                           expression='feq(Oa17_radiance, 323.09016273356974, 1.0e-4) ? NaN : Oa17_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa18_radiance = TargetBand(name='Oa18_radiance', 
                           expression='feq(Oa18_radiance, 360.4175960831344, 1.0e-4) ? NaN : Oa18_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa19_radiance = TargetBand(name='Oa19_radiance', 
                           expression='feq(Oa19_radiance, 329.54077841481194, 1.0e-4) ? NaN : Oa19_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa20_radiance = TargetBand(name='Oa20_radiance', 
                           expression='feq(Oa20_radiance, 213.89181678649038, 1.0e-4) ? NaN : Oa20_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
Oa21_radiance = TargetBand(name='Oa21_radiance', 
                           expression='feq(Oa21_radiance, 212.410729767289, 1.0e-4) ? NaN : Oa21_radiance',
                           unit='mW.m-2.sr-1.nm-1',
                           no_data_value='NaN')

# %%
band_maths.targetBandDescriptors = TargetBandDescriptors([Oa01_radiance, Oa02_radiance, Oa03_radiance, Oa04_radiance, Oa05_radiance,
                                                          Oa06_radiance, Oa07_radiance, Oa08_radiance, Oa09_radiance, Oa10_radiance, 
                                                          Oa11_radiance, Oa12_radiance, Oa13_radiance, Oa14_radiance, Oa15_radiance, 
                                                          Oa16_radiance, Oa17_radiance, Oa18_radiance, Oa19_radiance, Oa20_radiance, 
                                                          Oa21_radiance])

g.add_node(operator=band_maths, node_id="vicarious" ,source='Read')
# Out:
# targetBandDescriptors <snapista.target_band_descriptors.TargetBandDescriptors object at 0x0000020F7AD40B50>
# Instance TargetBandDescriptors: True
# Instance Aggregators: False
# Instance BinningOutputBands: False
# Instance BinningVariables: False
# Instance str: False

# %% [markdown]
# ##### ***Replace with re-calibrated bands and include idepix for c2rcc:***

# %%
merge = Operator("Merge", source=["Read", "vicarious", "Idepix"])
incl1 = "<include><productId>Idepix</productId><namePattern>pixel_classif_flags</namePattern></include>"
merge.includes = incl1
excl1 = "<exclude><productId>Read</productId><namePattern>Oa.*radiance</namePattern></exclude>"
merge.excludes = excl1

# %%
g.add_node(operator=merge, node_id="Merge", source=["Read", "vicarious", "Idepix"])
# Out:
# special case: nested parameter <excludes>
# <excludes><exclude><productId>Read</productId><namePattern>Oa.*radiance</namePattern></exclude>
#
# special case: nested parameter <includes>
# <includes><include><productId>Idepix</productId><namePattern>pixel_classif_flags</namePattern></include>

# %% [markdown]
# ##### **Add a 'MphChl' operator to the graph:***

# %%
validPixelExpression = '!quality_flags.invalid AND (!quality_flags.land || quality_flags.fresh_inland_water) and not pixel_classif_flags.IDEPIX_CLOUD'
mph_chl = Operator('MphChl', 
                   validPixelExpression=validPixelExpression, 
                   cyanoMaxValue='1000',
                   chlThreshForFloatFlag='500',
                   exportMph='True',
                   applyLowPassFilter='False')
g.add_node(operator=mph_chl, 
           node_id="mphchl",
           source='Merge')

# %% [markdown]
# ##### **Add a 'c2rcc.olci' operator to the graph:***

# %%
validPixelExpression = '!quality_flags.invalid AND (!quality_flags.land || quality_flags.fresh_inland_water) and not pixel_classif_flags.IDEPIX_CLOUD'
c2rcc_olci = Operator('c2rcc.olci',
                   validPixelExpression=validPixelExpression,
                   demName='GETASSE30',
                   thresholdCloudTDown865='0.95',
                   outputRhown='False',
                   outputUncertainties='False')
g.add_node(operator=c2rcc_olci, 
           node_id="c2rcc_tobecached",
           source='Merge')

# %% [markdown]
# ##### **Add a 'TileCache' operator to the c2rcc node:***

# %%
g.add_node(operator=Operator('TileCache', cacheSize='1200'), node_id="c2rcc" ,source='c2rcc_tobecached')

# %% [markdown]
# ##### **Add another 'BandMaths' operator to the graph for tsm computation:***

# %%
band_maths = Operator('BandMaths', source=["c2rcc", "mphchl"])

# %%
expression='(!nan($source.rhow_8) AND $source.rhow_8 &gt;= 0.0)?(((349.36 * $source.rhow_8) / (1 - $source.rhow_8 / 0.19503))):NaN'
spm_nechad_665 = TargetBand(name='spm_nechad_665', 
                           expression=expression,
                           description='spm_nechad_665 recalibration 2016',
                           type='float32',
                           unit='g m^-3',
                           no_data_value='NaN')

# %%
expression='(!nan($source.rhow_17) AND $source.rhow_17 &gt;= 0.0)?(((2920.05 * $source.rhow_17) / (1 - $source.rhow_17 / 0.21149))):NaN'
spm_nechad_865 = TargetBand(name='spm_nechad_865', 
                           expression=expression,
                           description='spm_nechad_865 recalibration 2016',
                           type='float32',
                           unit='g m^-3',
                           no_data_value='NaN')

# %%
expression='(!nan($source.rhow_8) AND $source.rhow_8 &gt;= 0.0)?(((374.75 * $source.rhow_8) / (1 - $source.rhow_8 / 0.19503))):NaN'
tur_nechad_665 = TargetBand(name='tur_nechad_665', 
                           expression=expression,
                           description='tur_nechad_665 recalibration 2016',
                           type='float32',
                           unit='FNU',
                           no_data_value='NaN')

# %%
expression='(!nan($source.rhow_17) AND $source.rhow_17 &gt;= 0.0)?(((3430.04 * $source.rhow_17) / (1 - $source.rhow_17 / 0.21149))):NaN'
tur_nechad_865 = TargetBand(name='tur_nechad_865', 
                           expression=expression,
                           description='tur_nechad_865 recalibration 2016',
                           type='float32',
                           unit='FNU',
                           no_data_value='NaN')

# %%
expression='(((($source.c2rcc_flags.Valid_PE) AND !nan($source.rhow_3)) AND (($source.c2rcc_flags.Valid_PE) AND !nan($source.rhow_4)) AND (($source.c2rcc_flags.Valid_PE) AND !nan($source.rhow_5)) AND (($source.c2rcc_flags.Valid_PE) AND !nan($source.rhow_6))))?(exp10(0.3255 + ((-2.7677 * pow(log10(max(max($source.rhow_3,$source.rhow_4),$source.rhow_5)/ $source.rhow_6) , 1)) + (2.4409 * pow(log10(max(max($source.rhow_3,$source.rhow_4),$source.rhow_5)/ $source.rhow_6), 2)) + (-1.1288 * pow(log10(max(max($source.rhow_3,$source.rhow_4),$source.rhow_5)/ $source.rhow_6), 3)) + (-0.4990 * pow(log10(max(max($source.rhow_3,$source.rhow_4),$source.rhow_5)/ $source.rhow_6), 4)) ))):NaN'    
chl_oc4 = TargetBand(name='chl_oc4', 
                           expression=expression,
                           description='chlorophyll oc4 NASA algorithm',
                           type='float32',
                           unit='mg m^-3',
                           no_data_value='NaN')

# %%
expression='($source.rhow_8 &gt;= 0.0 AND $source.rhow_4 &gt;= 0.0)?(6.557 * exp(-0.87372 * $source.rhow_8 / $source.rhow_4)):NaN'
c2rcc_secchi_depth_1 = TargetBand(name='c2rcc_secchi_depth_1', 
                           expression=expression,
                           description='secchi depth swedish algo 1',
                           type='float32',
                           unit='m',
                           no_data_value='NaN')

# %%
expression='($source.rhow_8 &gt;= 0.0 AND $source.rhow_4 &gt;= 0.0)?(6.557 * exp(-0.87372 * $source.rhow_8 / $source.rhow_4)):NaN'
c2rcc_secchi_depth_2 = TargetBand(name='c2rcc_secchi_depth_2', 
                           expression=expression,
                           description='secchi depth swedish algo 2',
                           type='float32',
                           unit='m',
                           no_data_value='NaN')

# %%
expression='($source.rhow_4 &gt;= 0.0 AND $source.rhow_11 &gt;= 0.0)?(2.137 * pow(($source.rhow_4 / $source.rhow_11),0.697)):NaN'
c2rcc_secchi_depth_3 = TargetBand(name='c2rcc_secchi_depth_3', 
                           expression=expression,
                           description='secchi depth swedish algo 3',
                           type='float32',
                           unit='m',
                           no_data_value='NaN')

# %%
expression='($source.rhow_6 &gt;= 0.0 AND !nan($source.kd489) AND !nan($source.iop_atot) AND !nan($source.iop_btot))?(log(((0.82-$source.rhow_6/PI) / $source.rhow_6/PI)/ 0.0066)/(-0.0001*pow(($source.kd489 + $source.iop_atot+$source.iop_btot),2)+ 0.7809*($source.kd489 + $source.iop_atot + $source.iop_btot) + 0.4026)):NaN'
c2rcc_secchi_depth_4 = TargetBand(name='c2rcc_secchi_depth_4', 
                           expression=expression,
                           description='secchi depth swedish algo 4',
                           type='float32',
                           unit='m',
                           no_data_value='NaN')

# %%
expression='0.8*$source.conc_chl'
chl_calib_c2rcc = TargetBand(name='chl_calib_c2rcc', 
                           expression=expression,
                           description='chl c2rcc calibrated for SWE WFD',
                           type='float32',
                           unit='mg m^-3',
                           no_data_value='NaN')

# %%
band_maths.targetBandDescriptors = TargetBandDescriptors([spm_nechad_665, spm_nechad_865, tur_nechad_665, tur_nechad_865, chl_oc4,
                                                          c2rcc_secchi_depth_1, c2rcc_secchi_depth_2, c2rcc_secchi_depth_3, c2rcc_secchi_depth_4, 
                                                          chl_calib_c2rcc])

g.add_node(operator=band_maths, node_id="tsm", source=["c2rcc", "mphchl"])
# Out:
# targetBandDescriptors <snapista.target_band_descriptors.TargetBandDescriptors object at 0x0000020F7AD40B50>
# Instance TargetBandDescriptors: True
# Instance Aggregators: False
# Instance BinningOutputBands: False
# Instance BinningVariables: False
# Instance str: False

# %% [markdown]
# ##### **Add another 'BandMaths' operator to the graph for 'sd_nechad' computation:***

# %%
band_maths = Operator('BandMaths', source=["tsm"])

# %%
expression='2.25710396*pow(tur_nechad_865,-0.6433607)'
SD_865 = TargetBand(name='SD_865', 
                           expression=expression,
                           description='SD Nechad 865',
                           type='float32',
                           unit='',
                           no_data_value='NaN')

# %%
expression='1.99620396*pow(tur_nechad_665,-1.293607)'
SD_665 = TargetBand(name='SD_665', 
                           expression=expression,
                           description='SD Nechad 665',
                           type='float32',
                           unit='',
                           no_data_value='NaN')

# %%
band_maths.targetBandDescriptors = TargetBandDescriptors([SD_865, SD_665])
g.add_node(operator=band_maths, node_id="sd_nechad", source=["tsm"])
# Out:
# targetBandDescriptors <snapista.target_band_descriptors.TargetBandDescriptors object at 0x0000020F7AD0F200>
# Instance TargetBandDescriptors: True
# Instance Aggregators: False
# Instance BinningOutputBands: False
# Instance BinningVariables: False
# Instance str: False

# %% [markdown]
# ##### **Add another 'BandMaths' operator to the graph for 'sd_gaussian' computation:***

# %%
band_maths = Operator('BandMaths', source=["c2rcc", "sd_nechad"])

# %%
expression='$source.1.SD_665 * ((exp(-pow($source.1.SD_865 - 2, 2.) / (2 * pow(0.5, 2)))+exp(-pow($source.conc_chl - 15, 2.) / (2 * pow(3, 2))))/2) + $source.1.SD_865 * (1-((exp(-pow($source.1.SD_865 - 2, 2.) / (2 * pow(0.5, 2)))+exp(-pow($source.conc_chl - 15, 2.) / (2 * pow(3, 2))))/2))'
secchi_depth_gaussian = TargetBand(name='secchi_depth_gaussian', 
                           expression=expression,
                           description='SD gaussian',
                           type='float32',
                           unit='',
                           no_data_value='NaN')

# %%
band_maths.targetBandDescriptors = TargetBandDescriptors([secchi_depth_gaussian])
g.add_node(operator=band_maths, node_id="sd_gaussian", source=["c2rcc", "sd_nechad"])
# Out:
# targetBandDescriptors <snapista.target_band_descriptors.TargetBandDescriptors object at 0x0000020F7AD0F200>
# Instance TargetBandDescriptors: True
# Instance Aggregators: False
# Instance BinningOutputBands: False
# Instance BinningVariables: False
# Instance str: False

# %% [markdown]
# ##### **Add another 'BandMaths' operator to the graph for 'secchidepth' computation:***

# %%
band_maths = Operator('BandMaths', source=["c2rcc", "sd_nechad", "sd_gaussian"])

# %%
expression='if $source.conc_chl > 15 and $source.1.SD_865 > 2 then $source.1.SD_665 else if $source.conc_chl &lt; 15 and $source.conc_chl > 10  and $source.1.SD_865 &lt; 2 and $source.1.SD_865 > 1 then $source.2.secchi_depth_gaussian else $source.1.SD_865'
secchi_depth_gaus = TargetBand(name='secchi_depth_gaus', 
                           expression=expression,
                           description='SD based on merged SD_665 and SD_865',
                           type='float32',
                           unit='',
                           no_data_value='NaN')

# %%
band_maths.targetBandDescriptors = TargetBandDescriptors([secchi_depth_gaus])
g.add_node(operator=band_maths, node_id="secchidepth", source=["c2rcc", "sd_nechad", "sd_gaussian"])
# Out:
# targetBandDescriptors <snapista.target_band_descriptors.TargetBandDescriptors object at 0x0000020F7AD78670>
# Instance TargetBandDescriptors: True
# Instance Aggregators: False
# Instance BinningOutputBands: False
# Instance BinningVariables: False
# Instance str: False

# %% [markdown]
# ##### **Add another 'BandMaths' operator to the graph for 'calibrated_secchidepth' computation:***

# %%
band_maths = Operator('BandMaths', source=["secchidepth", "tsm"])

# %%
expression='1.6*$source.secchi_depth_gaus'
secchi_depth_calib_gaus = TargetBand(name='secchi_depth_calib_gaus', 
                           expression=expression,
                           description='SD based on merged SD_665 and SD_865 calibrated for SWE WFD',
                           type='float32',
                           unit='',
                           no_data_value='NaN')

# %%
expression='0.5+1.15*$source.1.c2rcc_secchi_depth_1'
secchi_depth_calib_1 = TargetBand(name='secchi_depth_calib_1', 
                           expression=expression,
                           description='secchi depth swedish algo 1 calibrated for SWE WFD',
                           type='float32',
                           unit='',
                           no_data_value='NaN')

# %%
expression='1.3*$source.1.c2rcc_secchi_depth_4'
secchi_depth_calib_4 = TargetBand(name='secchi_depth_calib_4', 
                           expression=expression,
                           description='secchi depth swedish algo 4 calibrated for SWE WFD',
                           type='float32',
                           unit='',
                           no_data_value='NaN')

# %%
band_maths.targetBandDescriptors = TargetBandDescriptors([secchi_depth_calib_gaus, secchi_depth_calib_1, secchi_depth_calib_4])
g.add_node(operator=band_maths, node_id="calibrated_secchidepth", source=["secchidepth", "tsm"])
# Out:
# targetBandDescriptors <snapista.target_band_descriptors.TargetBandDescriptors object at 0x0000020F7AD78AD0>
# Instance TargetBandDescriptors: True
# Instance Aggregators: False
# Instance BinningOutputBands: False
# Instance BinningVariables: False
# Instance str: False

# %% [markdown]
# ##### **Add another 'Merge' operator for the final merge of all derived quantities:***

# %%
final_merge = Operator("Merge", source=["c2rcc", "tsm", "mphchl", "secchidepth", "calibrated_secchidepth"])
excl1 = "<exclude><productId>c2rcc</productId><namePattern>kdmin</namePattern></exclude>"
excl2 = "<exclude><productId>c2rcc</productId><namePattern>rtoa_[123579]|rtoa_1[012345689]|rtoa_2[01]</namePattern></exclude>"
final_merge.excludes = excl1 + excl2

# %%
g.add_node(operator=final_merge, node_id="final_merge", source=["c2rcc", "tsm", "mphchl", "secchidepth", "calibrated_secchidepth"])
# Out:
# special case: nested parameter <excludes>
# <excludes><exclude><productId>c2rcc</productId><namePattern>kdmin</namePattern></exclude><exclude><productId>c2rcc</productId><namePattern>rtoa_[123579]|rtoa_1[012345689]|rtoa_2[01]</namePattern></exclude>

# %% [markdown]
# ##### ***Add a 'Write' operator to the graph. Define a NetCDF output file:***

# %%
result_filename = os.getcwd() + os.sep + 'results' + os.sep + 'snap_nb_olci_okosat_result.nc'
g.add_node(operator=Operator("Write", file=result_filename, formatName='NetCDF4-BEAM'), node_id="Write", source='final_merge')

# %% [markdown]
# ##### ***View the graph in XML representation:***

# %%
g.view()
# Out:
# <graph>
#   <version>1.0</version>
#   <node id="Read">
#     <operator>Read</operator>
#     <sources/>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <bandNames/>
#       <copyMetadata>true</copyMetadata>
#       <file>E:\olaf\bc\snap\snap_md\notebooks\new\data\subset_0_of_S3A_OL_1_EFR____20180509T101337_20180509T101637_20180510T150001_0179_031_065_1980_MAR_O_NT_002.nc</file>
#       <formatName/>
#       <geometryRegion/>
#       <maskNames/>
#       <pixelRegion/>
#       <polygonRegion/>
#       <useAdvancedOptions>false</useAdvancedOptions>
#       <vectorFile/>
#     </parameters>
#   </node>
#   <node id="idepix_tobecached">
#     <operator>Idepix.Olci</operator>
#     <sources>
#       <sourceProduct refid="Read"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <alternativeCtpNNDir/>
#       <alternativeNNFile/>
#       <alternativeNNThresholdsFile/>
#       <cloudBufferWidth>2</cloudBufferWidth>
#       <computeCloudBuffer>true</computeCloudBuffer>
#       <computeCloudShadow>true</computeCloudShadow>
#       <computeMountainShadow>true</computeMountainShadow>
#       <mntShadowExtent>0.9</mntShadowExtent>
#       <outputCtp>false</outputCtp>
#       <outputSchillerNNValue>false</outputSchillerNNValue>
#       <radianceBandsToCopy/>
#       <reflBandsToCopy/>
#       <useLakeAndSeaIceClimatology>false</useLakeAndSeaIceClimatology>
#       <useO2HarmonizedRadiancesForNN>true</useO2HarmonizedRadiancesForNN>
#       <useSrtmLandWaterMask>false</useSrtmLandWaterMask>
#     </parameters>
#   </node>
#   <node id="idepix">
#     <operator>TileCache</operator>
#     <sources>
#       <source refid="idepix_tobecached"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <cacheSize>300</cacheSize>
#     </parameters>
#   </node>
#   <node id="vicarious">
#     <operator>BandMaths</operator>
#     <sources>
#       <source refid="Read"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <targetBands>
#         <targetBand>
#           <name>Oa01_radiance</name>
#           <expression>feq(Oa01_radiance, 913.9812317630276, 1.0e-4) ? NaN : Oa01_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa02_radiance</name>
#           <expression>feq(Oa02_radiance, 877.334085884504, 1.0e-4) ? NaN : Oa02_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa03_radiance</name>
#           <expression>feq(Oa03_radiance, 796.1270730709657, 1.0e-4) ? NaN : Oa03_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa04_radiance</name>
#           <expression>feq(Oa04_radiance, 754.9514318397269, 1.0e-4) ? NaN : Oa04_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa05_radiance</name>
#           <expression>feq(Oa05_radiance, 661.5928710484877, 1.0e-4) ? NaN : Oa05_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa06_radiance</name>
#           <expression>feq(Oa06_radiance, 809.60629854351287, 1.0e-4) ? NaN : Oa06_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa07_radiance</name>
#           <expression>feq(Oa07_radiance, 576.1581395426765, 1.0e-4) ? NaN : Oa07_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa08_radiance</name>
#           <expression>feq(Oa08_radiance, 574.4398430082947, 1.0e-4) ? NaN : Oa08_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa09_radiance</name>
#           <expression>feq(Oa09_radiance, 623.2575185084715, 1.0e-4) ? NaN : Oa09_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa10_radiance</name>
#           <expression>feq(Oa10_radiance, 506.83326963800937, 1.0e-4) ? NaN : Oa10_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa11_radiance</name>
#           <expression>feq(Oa11_radiance, 442.70399916451424, 1.0e-4) ? NaN : Oa11_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa12_radiance</name>
#           <expression>feq(Oa12_radiance, 471.8257776950486, 1.0e-4) ? NaN : Oa12_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa13_radiance</name>
#           <expression>feq(Oa13_radiance, 491.30539988866076, 1.0e-4) ? NaN : Oa13_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa14_radiance</name>
#           <expression>feq(Oa14_radiance, 566.9563756557181, 1.0e-4) ? NaN : Oa14_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa15_radiance</name>
#           <expression>feq(Oa15_radiance, 345.2246211259626, 1.0e-4) ? NaN : Oa15_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa16_radiance</name>
#           <expression>feq(Oa16_radiance, 347.5104749179445, 1.0e-4) ? NaN : Oa16_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa17_radiance</name>
#           <expression>feq(Oa17_radiance, 323.09016273356974, 1.0e-4) ? NaN : Oa17_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa18_radiance</name>
#           <expression>feq(Oa18_radiance, 360.4175960831344, 1.0e-4) ? NaN : Oa18_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa19_radiance</name>
#           <expression>feq(Oa19_radiance, 329.54077841481194, 1.0e-4) ? NaN : Oa19_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa20_radiance</name>
#           <expression>feq(Oa20_radiance, 213.89181678649038, 1.0e-4) ? NaN : Oa20_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>Oa21_radiance</name>
#           <expression>feq(Oa21_radiance, 212.410729767289, 1.0e-4) ? NaN : Oa21_radiance</expression>
#           <type>float32</type>
#           <description/>
#           <unit>mW.m-2.sr-1.nm-1</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#       </targetBands>
#       <variables/>
#     </parameters>
#   </node>
#   <node id="Merge">
#     <operator>Merge</operator>
#     <sources>
#       <masterProduct refid="Read"/>
#       <source.1 refid="vicarious"/>
#       <source.2 refid="Idepix"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <excludes>
#         <exclude>
#           <productId>Read</productId>
#           <namePattern>Oa.*radiance</namePattern>
#         </exclude>
#       </excludes>
#       <geographicError>1.0E-5f</geographicError>
#       <includes>
#         <include>
#           <productId>Idepix</productId>
#           <namePattern>pixel_classif_flags</namePattern>
#         </include>
#       </includes>
#     </parameters>
#   </node>
#   <node id="mphchl">
#     <operator>MphChl</operator>
#     <sources>
#       <sourceProduct refid="Merge"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <applyLowPassFilter>False</applyLowPassFilter>
#       <chlThreshForFloatFlag>500</chlThreshForFloatFlag>
#       <cyanoMaxValue>1000</cyanoMaxValue>
#       <exportMph>True</exportMph>
#       <validPixelExpression>!quality_flags.invalid AND (!quality_flags.land || quality_flags.fresh_inland_water) and not pixel_classif_flags.IDEPIX_CLOUD</validPixelExpression>
#     </parameters>
#   </node>
#   <node id="c2rcc_tobecached">
#     <operator>c2rcc.olci</operator>
#     <sources>
#       <sourceProduct refid="Merge"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <CHLexp>1.04</CHLexp>
#       <CHLfak>21.0</CHLfak>
#       <TSMfakBpart>1.06</TSMfakBpart>
#       <TSMfakBwit>0.942</TSMfakBwit>
#       <alternativeNNPath/>
#       <atmosphericAuxDataPath/>
#       <demName>GETASSE30</demName>
#       <deriveRwFromPathAndTransmittance>false</deriveRwFromPathAndTransmittance>
#       <outputAcReflectance>true</outputAcReflectance>
#       <outputAsRrs>false</outputAsRrs>
#       <outputKd>true</outputKd>
#       <outputOos>false</outputOos>
#       <outputRhown>False</outputRhown>
#       <outputRpath>false</outputRpath>
#       <outputRtoa>true</outputRtoa>
#       <outputRtosaGc>false</outputRtosaGc>
#       <outputRtosaGcAann>false</outputRtosaGcAann>
#       <outputTdown>false</outputTdown>
#       <outputTup>false</outputTup>
#       <outputUncertainties>False</outputUncertainties>
#       <ozone>330</ozone>
#       <press>1000</press>
#       <salinity>35.0</salinity>
#       <temperature>15.0</temperature>
#       <thresholdAcReflecOos>0.15</thresholdAcReflecOos>
#       <thresholdCloudTDown865>0.95</thresholdCloudTDown865>
#       <thresholdRtosaOOS>0.01</thresholdRtosaOOS>
#       <useEcmwfAuxData>true</useEcmwfAuxData>
#       <validPixelExpression>!quality_flags.invalid AND (!quality_flags.land || quality_flags.fresh_inland_water) and not pixel_classif_flags.IDEPIX_CLOUD</validPixelExpression>
#     </parameters>
#   </node>
#   <node id="c2rcc">
#     <operator>TileCache</operator>
#     <sources>
#       <source refid="c2rcc_tobecached"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <cacheSize>1200</cacheSize>
#     </parameters>
#   </node>
#   <node id="tsm">
#     <operator>BandMaths</operator>
#     <sources>
#       <source refid="c2rcc"/>
#       <source.1 refid="mphchl"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <targetBands>
#         <targetBand>
#           <name>spm_nechad_665</name>
#           <expression>(!nan($source.rhow_8) AND $source.rhow_8 &gt;= 0.0)?(((349.36 * $source.rhow_8) / (1 - $source.rhow_8 / 0.19503))):NaN</expression>
#           <type>float32</type>
#           <description>spm_nechad_665 recalibration 2016</description>
#           <unit>g m^-3</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>spm_nechad_865</name>
#           <expression>(!nan($source.rhow_17) AND $source.rhow_17 &gt;= 0.0)?(((2920.05 * $source.rhow_17) / (1 - $source.rhow_17 / 0.21149))):NaN</expression>
#           <type>float32</type>
#           <description>spm_nechad_865 recalibration 2016</description>
#           <unit>g m^-3</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>tur_nechad_665</name>
#           <expression>(!nan($source.rhow_8) AND $source.rhow_8 &gt;= 0.0)?(((374.75 * $source.rhow_8) / (1 - $source.rhow_8 / 0.19503))):NaN</expression>
#           <type>float32</type>
#           <description>tur_nechad_665 recalibration 2016</description>
#           <unit>FNU</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>tur_nechad_865</name>
#           <expression>(!nan($source.rhow_17) AND $source.rhow_17 &gt;= 0.0)?(((3430.04 * $source.rhow_17) / (1 - $source.rhow_17 / 0.21149))):NaN</expression>
#           <type>float32</type>
#           <description>tur_nechad_865 recalibration 2016</description>
#           <unit>FNU</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>chl_oc4</name>
#           <expression>(((($source.c2rcc_flags.Valid_PE) AND !nan($source.rhow_3)) AND (($source.c2rcc_flags.Valid_PE) AND !nan($source.rhow_4)) AND (($source.c2rcc_flags.Valid_PE) AND !nan($source.rhow_5)) AND (($source.c2rcc_flags.Valid_PE) AND !nan($source.rhow_6))))?(exp10(0.3255 + ((-2.7677 * pow(log10(max(max($source.rhow_3,$source.rhow_4),$source.rhow_5)/ $source.rhow_6) , 1)) + (2.4409 * pow(log10(max(max($source.rhow_3,$source.rhow_4),$source.rhow_5)/ $source.rhow_6), 2)) + (-1.1288 * pow(log10(max(max($source.rhow_3,$source.rhow_4),$source.rhow_5)/ $source.rhow_6), 3)) + (-0.4990 * pow(log10(max(max($source.rhow_3,$source.rhow_4),$source.rhow_5)/ $source.rhow_6), 4)) ))):NaN</expression>
#           <type>float32</type>
#           <description>chlorophyll oc4 NASA algorithm</description>
#           <unit>mg m^-3</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>c2rcc_secchi_depth_1</name>
#           <expression>($source.rhow_8 &gt;= 0.0 AND $source.rhow_4 &gt;= 0.0)?(6.557 * exp(-0.87372 * $source.rhow_8 / $source.rhow_4)):NaN</expression>
#           <type>float32</type>
#           <description>secchi depth swedish algo 1</description>
#           <unit>m</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>c2rcc_secchi_depth_2</name>
#           <expression>($source.rhow_8 &gt;= 0.0 AND $source.rhow_4 &gt;= 0.0)?(6.557 * exp(-0.87372 * $source.rhow_8 / $source.rhow_4)):NaN</expression>
#           <type>float32</type>
#           <description>secchi depth swedish algo 2</description>
#           <unit>m</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>c2rcc_secchi_depth_3</name>
#           <expression>($source.rhow_4 &gt;= 0.0 AND $source.rhow_11 &gt;= 0.0)?(2.137 * pow(($source.rhow_4 / $source.rhow_11),0.697)):NaN</expression>
#           <type>float32</type>
#           <description>secchi depth swedish algo 3</description>
#           <unit>m</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>c2rcc_secchi_depth_4</name>
#           <expression>($source.rhow_6 &gt;= 0.0 AND !nan($source.kd489) AND !nan($source.iop_atot) AND !nan($source.iop_btot))?(log(((0.82-$source.rhow_6/PI) / $source.rhow_6/PI)/ 0.0066)/(-0.0001*pow(($source.kd489 + $source.iop_atot+$source.iop_btot),2)+ 0.7809*($source.kd489 + $source.iop_atot + $source.iop_btot) + 0.4026)):NaN</expression>
#           <type>float32</type>
#           <description>secchi depth swedish algo 4</description>
#           <unit>m</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>chl_calib_c2rcc</name>
#           <expression>0.8*$source.conc_chl</expression>
#           <type>float32</type>
#           <description>chl c2rcc calibrated for SWE WFD</description>
#           <unit>mg m^-3</unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#       </targetBands>
#       <variables/>
#     </parameters>
#   </node>
#   <node id="sd_nechad">
#     <operator>BandMaths</operator>
#     <sources>
#       <source refid="tsm"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <targetBands>
#         <targetBand>
#           <name>SD_865</name>
#           <expression>2.25710396*pow(tur_nechad_865,-0.6433607)</expression>
#           <type>float32</type>
#           <description>SD Nechad 865</description>
#           <unit></unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>SD_665</name>
#           <expression>1.99620396*pow(tur_nechad_665,-1.293607)</expression>
#           <type>float32</type>
#           <description>SD Nechad 665</description>
#           <unit></unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#       </targetBands>
#       <variables/>
#     </parameters>
#   </node>
#   <node id="sd_gaussian">
#     <operator>BandMaths</operator>
#     <sources>
#       <source refid="c2rcc"/>
#       <source.1 refid="sd_nechad"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <targetBands>
#         <targetBand>
#           <name>secchi_depth_gaussian</name>
#           <expression>$source.1.SD_665 * ((exp(-pow($source.1.SD_865 - 2, 2.) / (2 * pow(0.5, 2)))+exp(-pow($source.conc_chl - 15, 2.) / (2 * pow(3, 2))))/2) + $source.1.SD_865 * (1-((exp(-pow($source.1.SD_865 - 2, 2.) / (2 * pow(0.5, 2)))+exp(-pow($source.conc_chl - 15, 2.) / (2 * pow(3, 2))))/2))</expression>
#           <type>float32</type>
#           <description>SD gaussian</description>
#           <unit></unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#       </targetBands>
#       <variables/>
#     </parameters>
#   </node>
#   <node id="secchidepth">
#     <operator>BandMaths</operator>
#     <sources>
#       <source refid="c2rcc"/>
#       <source.1 refid="sd_nechad"/>
#       <source.2 refid="sd_gaussian"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <targetBands>
#         <targetBand>
#           <name>secchi_depth_gaus</name>
#           <expression>if $source.conc_chl > 15 and $source.1.SD_865 > 2 then $source.1.SD_665 else if $source.conc_chl &lt; 15 and $source.conc_chl > 10  and $source.1.SD_865 &lt; 2 and $source.1.SD_865 > 1 then $source.2.secchi_depth_gaussian else $source.1.SD_865</expression>
#           <type>float32</type>
#           <description>SD based on merged SD_665 and SD_865</description>
#           <unit></unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#       </targetBands>
#       <variables/>
#     </parameters>
#   </node>
#   <node id="calibrated_secchidepth">
#     <operator>BandMaths</operator>
#     <sources>
#       <source refid="secchidepth"/>
#       <source.1 refid="tsm"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <targetBands>
#         <targetBand>
#           <name>secchi_depth_calib_gaus</name>
#           <expression>1.6*$source.secchi_depth_gaus</expression>
#           <type>float32</type>
#           <description>SD based on merged SD_665 and SD_865 calibrated for SWE WFD</description>
#           <unit></unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>secchi_depth_calib_1</name>
#           <expression>0.5+1.15*$source.1.c2rcc_secchi_depth_1</expression>
#           <type>float32</type>
#           <description>secchi depth swedish algo 1 calibrated for SWE WFD</description>
#           <unit></unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#         <targetBand>
#           <name>secchi_depth_calib_4</name>
#           <expression>1.3*$source.1.c2rcc_secchi_depth_4</expression>
#           <type>float32</type>
#           <description>secchi depth swedish algo 4 calibrated for SWE WFD</description>
#           <unit></unit>
#           <no_data_value>NaN</no_data_value>
#         </targetBand>
#       </targetBands>
#       <variables/>
#     </parameters>
#   </node>
#   <node id="final_merge">
#     <operator>Merge</operator>
#     <sources>
#       <masterProduct refid="c2rcc"/>
#       <source.1 refid="tsm"/>
#       <source.2 refid="mphchl"/>
#       <source.3 refid="secchidepth"/>
#       <source.4 refid="calibrated_secchidepth"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <excludes>
#         <exclude>
#           <productId>c2rcc</productId>
#           <namePattern>kdmin</namePattern>
#         </exclude>
#         <exclude>
#           <productId>c2rcc</productId>
#           <namePattern>rtoa_[123579]|rtoa_1[012345689]|rtoa_2[01]</namePattern>
#         </exclude>
#       </excludes>
#       <geographicError>1.0E-5f</geographicError>
#       <includes/>
#     </parameters>
#   </node>
#   <node id="Write">
#     <operator>Write</operator>
#     <sources>
#       <sourceProduct refid="final_merge"/>
#     </sources>
#     <parameters class="com.bc.ceres.binding.dom.XppDomElement">
#       <clearCacheAfterRowWrite>false</clearCacheAfterRowWrite>
#       <deleteOutputOnFailure>true</deleteOutputOnFailure>
#       <file>E:\olaf\bc\snap\snap_md\notebooks\new\results\snap_nb_olci_okosat_result.nc</file>
#       <formatName>NetCDF4-BEAM</formatName>
#       <writeEntireTileRows>false</writeEntireTileRows>
#     </parameters>
#   </node>
# </graph>

# %% [markdown]
# ##### ***Save the graph as XML file to disk:***

# %%
saved_graph_name = os.getcwd() + os.sep + 'graphs' + os.sep + 'snap_nb_olci_okosat.xml'
g.save_graph(saved_graph_name)

# %% [markdown]
# ##### ***Run the graph via SNAPISTA:***

# %%
g.run()
# Out:
# Processing the graph, this may take a while. Please wait...
# standard output of subprocess:
# Executing processing graph
# Initializing Desmile Auxiliary Data
# 12%25%37%50%62%75%87%100% done.
# Executing CTP processing...
#  done.
# bandIndex = 13
# bandIndex = 14
# bandIndex = 15
#
# 100% done.
#
# 100% done.
#
# 100% done.
#
# 100% done.
#
# 100% done.
#
# 100% done.
# .10%.21%...37%..47%.58%.68%.79%...95%
# 100% done.
#  done.
# standard error of subprocess:
# INFO: org.esa.snap.core.gpf.operators.tooladapter.ToolAdapterIO: Initializing external tool adapters
# INFO: org.esa.snap.core.util.EngineVersionCheckActivator: Please check regularly for new updates for the best SNAP experience.
# [main] INFO hdf.hdflib.HDFLibrary - HDF4 library:
# [main] INFO hdf.hdflib.HDFLibrary -  successfully loaded.
# [main] INFO hdf.hdf5lib.H5 - HDF5 library:
# [main] INFO hdf.hdf5lib.H5 -  successfully loaded.
# WARNING: org.esa.snap.dataio.netcdf.util.MetadataUtils: Missing configuration property 'snap.dataio.netcdf.metadataElementLimit'. Using default (100).
# WARNING: org.esa.snap.dataio.netcdf.util.MetadataUtils: Missing configuration property 'snap.dataio.netcdf.metadataElementLimit'. Using default (100).
# 2026-02-11 23:47:10.864538: I tensorflow/cc/saved_model/reader.cc:31] Reading SavedModel from: C:\Users\olafd\.snap\auxdata\idepix_olci\nn_ctp\nn_training_20190131_I7x30x30x30x10x2xO1
# 2026-02-11 23:47:10.865430: I tensorflow/cc/saved_model/reader.cc:54] Reading meta graph with tags { serve }
# 2026-02-11 23:47:10.866041: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# 2026-02-11 23:47:10.870161: I tensorflow/cc/saved_model/loader.cc:202] Restoring SavedModel bundle.
# 2026-02-11 23:47:10.883075: I tensorflow/cc/saved_model/loader.cc:311] SavedModel load for tags { serve }; Status: success. Took 18526 microseconds.
# WARNING: org.esa.snap.dataio.netcdf.util.MetadataUtils: Missing configuration property 'snap.dataio.netcdf.metadataElementLimit'. Using default (100).
# WARNING: org.esa.snap.core.gpf.internal.TileCacheOp: You are using TileCache operator. Be aware that it is an experimental implementation.
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 300 assigned to PlanarImage[minX=0 minY=0 width=1200 height=1200 tileGridXOffset=0 tileGridYOffset=0 tileWidth=600 tileHeight=600 sampleModel=ComponentSampleModelJAI:   dataType=4  numBands=1  width=600  height=600  bandOffsets=[ 0 ] colorModel=FloatDoubleColorModel: ColorModel: #pixelBits = 32 numComponents = 1 color space = java.awt.color.ICC_ColorSpace@bff764c transparency = 1 has alpha = false isAlphaPre = false]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 300 assigned to PlanarImage[minX=0 minY=0 width=1200 height=1200 tileGridXOffset=0 tileGridYOffset=0 tileWidth=600 tileHeight=600 sampleModel=ComponentSampleModelJAI:   dataType=4  numBands=1  width=600  height=600  bandOffsets=[ 0 ] colorModel=FloatDoubleColorModel: ColorModel: #pixelBits = 32 numComponents = 1 color space = java.awt.color.ICC_ColorSpace@bff764c transparency = 1 has alpha = false isAlphaPre = false]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 300 assigned to OperatorImage[Idepix.Olci.Postprocess,pixel_classif_flags]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 300 assigned to PlanarImage[minX=0 minY=0 width=1200 height=1200 tileGridXOffset=0 tileGridYOffset=0 tileWidth=600 tileHeight=600 sampleModel=ComponentSampleModelJAI:   dataType=3  numBands=1  width=600  height=600  bandOffsets=[ 0 ] colorModel=ColorModel: #pixelBits = 32 numComponents = 1 color space = java.awt.color.ICC_ColorSpace@bff764c transparency = 1 has alpha = false isAlphaPre = false]
# INFO: eu.esa.opt.c2rcc.olci.C2rccOlciOperator: c2rcc initial tile : null, configured tile: java.awt.Dimension[width=1217,height=1023]
# WARNING: org.esa.snap.core.gpf.internal.TileCacheOp: You are using TileCache operator. Be aware that it is an experimental implementation.
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to PlanarImage[minX=0 minY=0 width=1200 height=1200 tileGridXOffset=0 tileGridYOffset=0 tileWidth=600 tileHeight=600 sampleModel=ComponentSampleModelJAI:   dataType=4  numBands=1  width=600  height=600  bandOffsets=[ 0 ] colorModel=FloatDoubleColorModel: ColorModel: #pixelBits = 32 numComponents = 1 color space = java.awt.color.ICC_ColorSpace@bff764c transparency = 1 has alpha = false isAlphaPre = false]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to PlanarImage[minX=0 minY=0 width=1200 height=1200 tileGridXOffset=0 tileGridYOffset=0 tileWidth=600 tileHeight=600 sampleModel=ComponentSampleModelJAI:   dataType=4  numBands=1  width=600  height=600  bandOffsets=[ 0 ] colorModel=FloatDoubleColorModel: ColorModel: #pixelBits = 32 numComponents = 1 color space = java.awt.color.ICC_ColorSpace@bff764c transparency = 1 has alpha = false isAlphaPre = false]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to PlanarImage[minX=0 minY=0 width=1200 height=1200 tileGridXOffset=0 tileGridYOffset=0 tileWidth=600 tileHeight=600 sampleModel=ComponentSampleModelJAI:   dataType=3  numBands=1  width=600  height=600  bandOffsets=[ 0 ] colorModel=ColorModel: #pixelBits = 32 numComponents = 1 color space = java.awt.color.ICC_ColorSpace@bff764c transparency = 1 has alpha = false isAlphaPre = false]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImage[Idepix.Olci.Postprocess,pixel_classif_flags]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_1]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_2]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_3]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_4]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_5]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_6]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_7]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_8]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_9]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_10]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_11]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_12]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_13]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_14]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_15]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_16]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_17]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_18]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_19]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_20]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rtoa_21]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_1]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_2]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_3]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_4]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_5]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_6]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_7]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_8]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_9]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_10]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_11]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_12]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_16]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_17]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_18]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,rhow_21]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,iop_apig]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,iop_adet]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,iop_agelb]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,iop_bpart]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,iop_bwit]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to PlanarImage[minX=0 minY=0 width=1200 height=1200 tileGridXOffset=0 tileGridYOffset=0 tileWidth=1217 tileHeight=1023 sampleModel=ComponentSampleModelJAI:   dataType=4  numBands=1  width=1217  height=1023  bandOffsets=[ 0 ] colorModel=FloatDoubleColorModel: ColorModel: #pixelBits = 32 numComponents = 1 color space = java.awt.color.ICC_ColorSpace@bff764c transparency = 1 has alpha = false isAlphaPre = false]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to PlanarImage[minX=0 minY=0 width=1200 height=1200 tileGridXOffset=0 tileGridYOffset=0 tileWidth=1217 tileHeight=1023 sampleModel=ComponentSampleModelJAI:   dataType=4  numBands=1  width=1217  height=1023  bandOffsets=[ 0 ] colorModel=FloatDoubleColorModel: ColorModel: #pixelBits = 32 numComponents = 1 color space = java.awt.color.ICC_ColorSpace@bff764c transparency = 1 has alpha = false isAlphaPre = false]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to PlanarImage[minX=0 minY=0 width=1200 height=1200 tileGridXOffset=0 tileGridYOffset=0 tileWidth=1217 tileHeight=1023 sampleModel=ComponentSampleModelJAI:   dataType=4  numBands=1  width=1217  height=1023  bandOffsets=[ 0 ] colorModel=FloatDoubleColorModel: ColorModel: #pixelBits = 32 numComponents = 1 color space = java.awt.color.ICC_ColorSpace@bff764c transparency = 1 has alpha = false isAlphaPre = false]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,kd489]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,kdmin]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to PlanarImage[minX=0 minY=0 width=1200 height=1200 tileGridXOffset=0 tileGridYOffset=0 tileWidth=1217 tileHeight=1023 sampleModel=ComponentSampleModelJAI:   dataType=4  numBands=1  width=1217  height=1023  bandOffsets=[ 0 ] colorModel=FloatDoubleColorModel: ColorModel: #pixelBits = 32 numComponents = 1 color space = java.awt.color.ICC_ColorSpace@bff764c transparency = 1 has alpha = false isAlphaPre = false]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to PlanarImage[minX=0 minY=0 width=1200 height=1200 tileGridXOffset=0 tileGridYOffset=0 tileWidth=1217 tileHeight=1023 sampleModel=ComponentSampleModelJAI:   dataType=4  numBands=1  width=1217  height=1023  bandOffsets=[ 0 ] colorModel=FloatDoubleColorModel: ColorModel: #pixelBits = 32 numComponents = 1 color space = java.awt.color.ICC_ColorSpace@bff764c transparency = 1 has alpha = false isAlphaPre = false]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to PlanarImage[minX=0 minY=0 width=1200 height=1200 tileGridXOffset=0 tileGridYOffset=0 tileWidth=1217 tileHeight=1023 sampleModel=ComponentSampleModelJAI:   dataType=4  numBands=1  width=1217  height=1023  bandOffsets=[ 0 ] colorModel=FloatDoubleColorModel: ColorModel: #pixelBits = 32 numComponents = 1 color space = java.awt.color.ICC_ColorSpace@bff764c transparency = 1 has alpha = false isAlphaPre = false]
# INFO: org.esa.snap.core.gpf.internal.TileCacheOp: Local tile cache 1200 assigned to OperatorImageTileStack[c2rcc.olci,c2rcc_flags]
# [main] INFO serverStartup - Nc4Iosp: NetCDF-4 C library loaded (jna_path='C:\Users\olafd\.snap\auxdata\netcdf_natives\13.0.0\amd64', libname='netcdf').
# [main] INFO serverStartup - NetcdfLoader: set log level: old=0 new=0
# [main] INFO serverStartup - Nc4Iosp: set log level: old=0 new=0
# Processing finished successfully.
# 0
